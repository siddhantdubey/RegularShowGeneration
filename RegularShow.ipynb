# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhantdubey/RegularShowGeneration/blob/master/RegularShow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
# Out:
# TensorFlow 1.x selected.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob
import tensorflow as tf
import os
import requests

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/Folders/Siddhant Dubey/Data/stormlight/"
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import files

# %%
model_name = "124M"
if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)

# %%
file_name = root_dir + "combined.txt"

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              model_name=model_name,
              only_train_transformer_layers = True,
              accumulate_gradients = 1,
              steps=1000)
# Out:
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:03<00:00,  3.47s/it]
# dataset has 648357 tokens
# Training...
# [1 | 4.28] loss=2.94 avg=2.94
# [2 | 5.12] loss=2.30 avg=2.62
# [3 | 5.96] loss=2.40 avg=2.55
# [4 | 6.81] loss=2.75 avg=2.60
# [5 | 7.66] loss=3.12 avg=2.71
# [6 | 8.50] loss=2.62 avg=2.69
# [7 | 9.34] loss=2.60 avg=2.68
# [8 | 10.19] loss=2.55 avg=2.66
# [9 | 11.04] loss=2.81 avg=2.68
# [10 | 11.89] loss=2.94 avg=2.71
# [11 | 12.74] loss=2.35 avg=2.67
# [12 | 13.59] loss=2.65 avg=2.67
# [13 | 14.44] loss=2.84 avg=2.68
# [14 | 15.29] loss=2.77 avg=2.69
# [15 | 16.14] loss=2.77 avg=2.70
# [16 | 16.98] loss=2.49 avg=2.68
# [17 | 17.82] loss=2.48 avg=2.67
# [18 | 18.67] loss=2.72 avg=2.67
# [19 | 19.52] loss=2.61 avg=2.67
# [20 | 20.37] loss=2.71 avg=2.67
# [21 | 21.22] loss=2.46 avg=2.66
# [22 | 22.06] loss=2.71 avg=2.66
# [23 | 22.90] loss=3.11 avg=2.69
# ...

# %%
gpt2.generate(sess)
# Out:
# (Benson starts to walk away, but Mordecai is still chasing him.)
#
# Mordecai: (Laughs) I don't know, dude. I think he's just not ready yet.
#
# Rigby: (Looks at Rigby) I think he's got a few more weeks to really train.
#
# Mordecai: Ooh. I don't know. I guess he'll be ready by then.
#
# Rigby: I can't wait. I'm gonna go grab a soda. And get me some fresh air.
#
# Mordecai: (Laughs) Oh, man. I'm not gonna go there.
#
# Rigby: You're not going there.
#
# Mordecai: (Laughs) Maybe.
#
# (A drone flies over Mordecai.)
#
# Rigby: We're coming!
#
# Mordecai: (Laughs) I'm coming!
#
# (A drone flies over Mordecai.)
#
# Rigby: (Laughs) Come on, dude!
#
# (A drone flies over Rigby.)
#
# Rigby: (Laughs) Come on, dude!
#
# (A drone flies over Mordecai.)
#
# Rigby: Come on, dude!
#
# (A drone flies over Mordecai.)
#
# Rigby: Come on, dude!
#
# Mordecai: (Laughs) I'm coming!
#
# (A drone flies over Mordecai.)
#
# Rigby: Come on, dude!
#
# (A drone flies over Mordecai.)
#
# Rigby: Come on, dude!
#
# ...

# %%
gpt2.mount_gdrive()
gpt2.copy_checkpoint_to_gdrive(run_name='attempt1')
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-e106cc2a7ca3> in <module>()
#       1 gpt2.mount_gdrive()
# ----> 2 gpt2.copy_checkpoint_to_gdrive(run_name='attempt1')
#
# /usr/local/lib/python3.7/dist-packages/gpt_2_simple/gpt_2.py in copy_checkpoint_to_gdrive(run_name, copy_folder)
#     587         # Reference: https://stackoverflow.com/a/17081026
#     588         with tarfile.open(file_path, 'w') as tar:
# --> 589             tar.add(checkpoint_folder)
#     590
#     591         shutil.copyfile(file_path, "/content/drive/My Drive/" + file_path)
#
# /usr/lib/python3.7/tarfile.py in add(self, name, arcname, recursive, filter)
#    1926
#    1927         # Create a TarInfo object from the file.
# -> 1928         tarinfo = self.gettarinfo(name, arcname)
#    1929
#    1930         if tarinfo is None:
#
# ...

# %%
gpt2.generate(sess, length=15000, run_name='run1')
# Out:
# Cuts to the park bench, where HFG and HFG2 are standing)
#
# HFG:
#
# ...

# %%
gpt2.generate(sess,
              prefix="(Episode starts with Mordecai, Rigby, Pops, and Skips coming out of the theater after watching Scary Movie 4)",
              length=3000
              )
# Out:
# (Episode starts with Mordecai, Rigby, Pops, and Skips coming out of the theater after watching Scary Movie 4)
#
# Mordecai: Whoa. That was awesome.
#
# (There is a very angry audience member)
#
# Mordecai: Just a bunch of people watching that movie!
#
# Rigby: Yeah, it's terrible.
#
# Mordecai: Uh, look, I'm not gonna read it.
#
# Rigby: No, I'm watching it now.
#
# Mordecai: But, dude!
#
# Rigby: No, I'm gonna watch it now.
#
# Mordecai: You want to watch it now?
#
# Rigby: Yeah, I want to watch it now.
#
# (The audience members all start to run away)
#
# Mordecai: Rigby!
#
# (Rigby grabs the movie disc and starts to read the words "Say Goodbye" on the screen)
#
# Rigby: Don't touch it.
#
# (Rigby reads the words on screen)
#
# Rigby: "Dementia Dreams" by Tony Visconti.
#
# Mordecai: But it says "In The Flesh" on screen.
#
# Rigby: Yeah.
#
# ...

# %%
gpt2.generate(sess,
              prefix="Benson: HOW DID YOU GUYS BLOW UP THE KITCHEN?",
              temperature=0.5,
              length=8000
              )
# Out:
# Benson: HOW DID YOU GUYS BLOW UP THE KITCHEN?
#
# (Mordecai and Rigby laugh)
#
# Mordecai: Oh, he's cool.
#
# (Mordecai and Rigby laugh again)
#
# Rigby: Uh, I was just trying to save you, and I ended up breaking the kitch.
#
# Mordecai: (to Rigby) That's because you were too cool to break the kitch!
#
# Rigby: Oh, yeah. Well, I'll just have you know that the kitch is gonna go down.
#
# (Mordecai and Rigby laugh again)
#
# Rigby: Oh, yeah. That's a good one, Benson.
#
# Benson: (laughs) You're right. I'm sorry.
#
# Mordecai: (laughs) I'm sorry.
#
# (Mordecai and Rigby laugh again)
#
# Rigby: Oh, yeah. You're gonna like this one.
#
# Mordecai: (laughs) Yeah, you're gonna like that one.
#
# (Mordecai and Rigby laugh again)
#
# Rigby: Yeah, you're gonna like this one.
#
# Mordecai: (laughs) Yeah, you're gonna like that one.
#
# (Mordecai and Rigby laugh again)
#
# ...

# %%
gpt2.generate(sess,
              prefix="(Episode starts with Mordecai, Rigby, Pops, and Skips coming out of the theater after watching Scary Movie 4)",
              length=3000,
              temperature=0.8
              )
# Out:
# (Episode starts with Mordecai, Rigby, Pops, and Skips coming out of the theater after watching Scary Movie 4)
#
# Mordecai: Rigby. This is Mordecai and Rigby, and you two are jerks!
#
# Rigby: Yeah, I remember when you were a kid, you were like, "I hate you" and I was like, "What the-?" and I was like, "Haha, I can't help it".
#
# Mordecai: We're not really jerks.
#
# Rigby: Aw, yeah, right, that's its kinda cool.
#
# Mordecai: You know who else isn't cool?
#
# Rigby: http://www.youtube.com/watch?v=7GljWQHKNU
#
# (Pops can be heard from the balcony from the balcony, and is holding a bottle of Dew as Mordecai and Rigby screaming as they run over to the balcony)
#
# Mordecai: Dude, we gotta get out of here!
#
# (They run into the kitchen, and find Dew inside the kitchen cupboards)
#
# Rigby: More Dew?
#
# Mordecai: Yeah, he's not at the end of the cupboards.
#
# Rigby: Dude, we got Dew!
#
# Mordecai: Dude, that's not Dew.
#
# Rigby: Huh! That's not actually what it is!
#
# ...
