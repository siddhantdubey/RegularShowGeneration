# %%
import markovify

# %%
with open("data/combined.txt") as f:
    text = f.read()

# Build the model.
text_model = markovify.Text(text, well_formed=False)

# Print five randomly-generated sentences
for i in range(5):
    print(text_model.make_sentence())
# Out:
# He laughs in the Putterpalooza.
# Carrey O' Key's owner, the tape is seen) (Within this Offices) Margaret: Here's your punch.
# Mordecai: And why's it gotta be here by now.
# Mordecai and Rigby) Mordecai & Rigby look around, but I don't know.
# Benson: (Voiceover) It was the weirdest looking person, pull their bottle rockets, which pops out of it.

# %%
for i in range(100):
    print(text_model.make_short_sentence(100000) + '\n')
# Out:
# (Mordecai dials Margaret's cell phone number and the us toys (both throw the bus) Rigby: (coming out of it.
#
# (A commercial for the remainder of the garage] Thank you so uptight?! (The book splits in half.
#
# (Through the exit and go into Cart.)
#
# CJ: (laughs) Yeah, it is!
#
# Alright, you guys been?
#
# (We zooms in on them but they don't call me Fives.
#
# He doesn't trust me with this, grab some old fashion arm wrestling, eh?
#
# Sherm: Let me help.
#
# (Mordecai and Rigby climb out of my body with refined sugar anyway.
#
# (The people start to shred the whole time I've known you....But...how well do I do?
#
# He lowers the binoculars, seeing Pam entering the Mesosphere!
#
# Mordecai: Because I can fix it.
#
# Mordecai: We told him a card to confirm payment, his order prepared.)
#
# How's this for today.
#
# The reeds are still playing "I Ran", we see Muscle Man defeated the Wing Kingdom bag, stuffing napkins into it.
#
# Rigby: (on tape) What do I tell you, over and says "Captain Toilet", "Loser", while Rigby takes the box to reveal prototypes of the fan shred it, and gets inside) UGH!
#
# Which one of those trees.
#
# (The group uses a bookshelf.
#
# Benson: - Wait no, this is weird.
#
# (We go to Don's Tae Kwon Do, Sherm.
#
# Briggs: Take your pick!
#
# Mordecai: Come on, guys, those coughs sound pretty confident.
#
# You always laugh when you were too impatient for me to a wire with Mordecai, Rigby, Skips, and the bounty hunter uses his Tornado technique to defeat a dinosaur at all.
#
# They'll have all the snow monsters) Rigby: Eileen!
#
# (Benson blushes) Benson: Give me your keys.
#
# (takes off hat to reveal the words "ello gov'nor."
#
# Mordecai and Rigby bump into the table, sending the minions' ship flying out of his minions jumps onto the ground, and the cart to go find Benson.
#
# Or should I say, quite the handsome man in the background) African Person: Animals and.
#
# He was like, "Brah!"
#
# (slides his hand in front of him) Benson: Hey, you know any ducks?
#
# It's making me think about sneaking out!
#
# (Pops teleports outside of the moon and the song I requested!
#
# (at that moment, another spacecraft can be heard) Frank: Mordecai!
#
# Dramatic music plays as the mighty boomerang, our national weapon.
#
# Mordecai: The camera's gotta be a little stressed 'cause I'm (shoots) hungry!
#
# Mordecai: (pushes Rigby) Rigby's just freaked out by Reginald) Rigby: (catches the dodgeball) Hey, I tried to use the internet.
#
# Rigby: You're gonna have to end the experiment...push the button.
#
# Mordecai: So who's with me?! Rigby: Yeah right!
#
# Benson: Don't do that!
#
# Rigby: No offense, you guys.
#
# (Mr. Maellard puts his thumb up to him) Rigby: Hey, cool it!
#
# Louie punches Muscle Man's space soda breaks and the Guardians of Eternal Youth: AAAHHHH!
#
# (Hi Five Ghost are sitting on his back) Mordecai: Alright, fine, look, you're safe now.
#
# Benson: No, you two were made to do: you have no idea how long I can do.
#
# Rigby: Just give it back to the game has changed.
#
# Rigby: So this is finally able to stop the guy who's cultured.
#
# Rigby: Hey, nobody talks like that with your eyes on Benson.)
#
# (We zoom out of the day, fellas.
#
# Mordecai: Yeah, man, sandwiches!
#
# (He pulls out a chair and waving his shirt around while the crowd boos) Rigby: Dude, Friday!? Mordecai: Ugh!
#
# Skips is on the brake until the graphite on his shoulders and looks furious.
#
# Silently waiting for a walk when suddenly a ghost appears and shakes it; it causes the whole truth and nothing but static.)
#
# (Blu-ray puts a disc through his heart.
#
# Like I said, you're in!
#
# Mordecai, Rigby, CJ, and Eileen laugh) Margaret: Nice one.
#
# Usually I can explain!
#
# Mordicus: Marvolo, do you think that you reconsider- (Thomas cuts him off.)
#
# (At the outside of the door) Pizza!
#
# And I did it, my job.
#
# No we don't even have a long list stuff you find?
#
# They then break the winning streak I'm having.
#
# (Mordecai punches Rigby again) Rigby: Aw Yeayuh!
#
# Rigby: Uh, isn't that we're cool too.
#
# I don’t think I was just doing a pull-up.
#
# Lastly, Mount Rushmore is shown driving off in the kitchen.
#
# (Then he got shocked from the air in front of Iacedrom & Ygbir hiss and squawk, scaring Pops.
#
# Mordecai is getting a little rusty.
#
# The Erasing Beam is seen with a fat meerkat] -and look at Benson) Agh!
#
# All this scary stuff is making me uncomfortable with his back while Skips retreats, then the next scene shows Rigby walking through more walls.
#
# (Mordecai, Margaret, and Eileen are signing their names on the date, and she landing on the machine) Country Club Leader) Shouldn't have messed with his motorcyle.
#
# (Death rings the doorbell, which Skips activates by cutting some rope.
#
# (They smile at each other) Benson: It's not like I should probablyyyyyy.......
#
# No, we ain't gonna take care of any bank shot in history, we may kill you.
#
# It really is the one being honored tomorrow with the tennis player) Tennis Player: Argh, it smells like the opposite direction, before being blocked off by Mordecai, Rigby, and Skips are throwing rice at them.
#
# (Mordecai tries to get you back!
#
# (The scene changes to Thomas working at that time, sir.
#
# Mordecai: Yeah, we always save room...for donuts!
#
# (Muscle Man is seen shooting a gun.
#
# Benson: (a little annoyed) I didn't really taste anything.
#
# (The Geese are the rules.
#
# Rigby: Yeah, there must have eaten like a giant flat screen down to the next scene, teenage Mordecai plays rock.)
#
# (Rigby runs out the immunity sword was a great question, Pops.
#
# Meanwhile, Benson has just finished playing and explodes, and he screams while Mordecai looks around to face your destiny.
#
# All we got it.
#
# You will compete in a better liar than me.
#
# Rigby: (while running to catch the next big thing.
#
# (It attaches like a planet full of excitement) We have no idea.
#
# Mordecai: They're not even here.
#
# Mordecai: (Comes down the street.
#
# He opens a cabinet, but then he runs down the hall.)
#
# Rigby only wanted to be staring intently at a birthday at the file that Mordecai is going to go for a refresher course, cuz' all you're communicating here is the first plan never works.
#
# (walks off) I'll see you guys keep it under control.
#
# But she's too smart to be on our merry way.
#
# Rigby: (continues reading the newspaper along with Muscle Man's trailer.
#
# No time for this!
#
# Including from the two dudes that were actually true.
#
# (Punches the Country Club Leader) Shouldn't have messed with his paddle, then Rigby bites the Carter and Briggs are in their police cruiser, Gary's synthesizer down, only for HFG to stop cleaning those boats.
#
# Pops: (acts immature and turns on a date, and she and Rigby put the projector and shakes his head off, and quickly licks the chip crumbs) Dude, did you leave blank?
#
# (Mordecai and Rigby are setting up chairs.
#
# (Margaret holds Mordecai close) Muscle Man: But I don't know, Benson.

# %%
with open("data/Bad_Kiss.txt") as f:
    text = f.read()

# %%
len([c for c in text])
# Out:
# 14175
